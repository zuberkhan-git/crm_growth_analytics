# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('pipeline_left_joins_cleaned_5_23_24_01.csv')
df2 = pd.read_csv('pipeline_outer_joins_cleaned_5_23_24_01.csv')

# %%
# df_countries_fix = df.replace('Philipines','Philippines') #one at a time seems to be working... ignore during technical write-up

# %%
#df2_countries_fix = df2.replace('Philipines','Philippines') #... ignore during technical write-up

# %%
# df_countries_fix = df.replace('Korea','South Korea') #again, one at a time seems to be working. 
#code to verify is df_countries_fix[df_countries_fix['office_location'] == 'South Korea']    #then replace country name with erroneous one.

# %%
df2_countries_fix = df2.replace('Korea','South Korea')
#interesting. looks like South Korea worked but Philipines didn't. Let' try executing one at at time

# %%
df2_countries_fix[df2_countries_fix['office_location'] == 'Philipines'] #one at a time seems to be working
#ok. When I go back and check after having run multiple independently, the changes haven't been saved even though I assigned new df names. 
#probably need to figure out how to replace multiple values simultaneously, then export once done. Then do the same for the next df (left v outer)
# Out:
#      opportunity_id         sales_agent         product     account  \
# 25         M2TZSYTN         Moses Frase       GTX Basic  Bioholding
# 53         5G645WYV         Moses Frase    GTX Plus Pro  Bioholding
# 57         A89TBOY5         Moses Frase     MG Advanced  Bioholding
# 77         FZ1TTF0X         Moses Frase       GTX Basic  Bioholding
# 90         ZG1DFNPW         Moses Frase       GTX Basic  Bioholding
# 92         C2RL3DUQ         Moses Frase     MG Advanced  Bioholding
# 98         VUYQCXTY         Moses Frase  GTX Plus Basic  Bioholding
# 100        81LMZHD1         Moses Frase    GTX Plus Pro  Bioholding
# 132        6TOOTFQV         Moses Frase     MG Advanced  Bioholding
# 171        0F9GSZRO         Moses Frase       GTX Basic  Bioholding
# 197        ZDAJ4PFJ         Moses Frase       GTX Basic  Bioholding
# 206        69Z30MBF         Moses Frase       GTX Basic  Bioholding
# 223        6FR9YZH2         Moses Frase    GTX Plus Pro  Bioholding
# ...

# %%
#first 3 cells are to get established. New work that actually fixes issue goes from here down. starting 3:38pm 5/26/24
df_countries_fix = df.replace(['Philipines', 'Korea'], ['Philippines', 'South Korea'])

# %%
df_countries_fix[df_countries_fix['office_location'] == 'Philipines']  #this worked. Let's export now.
# Out:
# Empty DataFrame
# Columns: [opportunity_id, sales_agent, product, account, deal_stage, engage_date, close_date, close_value, series, sales_price, sector, year_established, revenue, employees, office_location, subsidiary_of, manager, regional_office]
# Index: []

# %%
file_path = 'all_left_joined_cntrys_fixed_5_26_24_01.csv'

# %%
df_countries_fix.to_csv(file_path, index=False)

# %%
#now let's repeat for my outer join df.
df2_countries_fix = df2.replace(['Philipines', 'Korea'], ['Philippines', 'South Korea'])

# %%
df2_countries_fix[df2_countries_fix['office_location'] == 'South Korea']  #this worked. Let's export now.
# Out:
#      opportunity_id         sales_agent         product   account  \
# 11         6389JY2H         Moses Frase      MG Special  Hottechi
# 19         XYBPUC2H         Moses Frase       GTX Basic  Hottechi
# 54         8FXUNDUS         Moses Frase     MG Advanced  Hottechi
# 97         QMJHLT1V         Moses Frase      MG Special  Hottechi
# 116        QE6A49LE         Moses Frase      MG Special  Hottechi
# 220        7GWM1WT0         Moses Frase       GTX Basic  Hottechi
# 326        TTJXSO57     Darcel Schlecht         GTX Pro  Hottechi
# 381        RX3F3VIU     Darcel Schlecht      MG Special  Hottechi
# 412        75S7S74S     Darcel Schlecht       GTX Basic  Hottechi
# 533        SYJKN818     Darcel Schlecht         GTX Pro  Hottechi
# 566        J3N73B00     Darcel Schlecht         GTX Pro  Hottechi
# 691        EY73E4ZB     Darcel Schlecht     MG Advanced  Hottechi
# 756        SZPU1DSR     Darcel Schlecht  GTX Plus Basic  Hottechi
# ...

# %%
file_path = 'all_outer_joined_cntrys_fixed_5_26_24_01.csv'

# %%
df2_countries_fix.to_csv(file_path, index=False)
#done fixing country typo and incompatibility issues at the df and csv level as of 3:53pm 5/26/24
