# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('sales_teams.csv')

# %%
df
# Out:
#            sales_agent           manager regional_office
# 0        Anna Snelling  Dustin Brinkmann         Central
# 1       Cecily Lampkin  Dustin Brinkmann         Central
# 2    Versie Hillebrand  Dustin Brinkmann         Central
# 3      Lajuana Vencill  Dustin Brinkmann         Central
# 4          Moses Frase  Dustin Brinkmann         Central
# 5   Jonathan Berthelot     Melvin Marxen         Central
# 6    Marty Freudenburg     Melvin Marxen         Central
# 7     Gladys Colclough     Melvin Marxen         Central
# 8      Niesha Huffines     Melvin Marxen         Central
# 9      Darcel Schlecht     Melvin Marxen         Central
# 10       Mei-Mei Johns     Melvin Marxen         Central
# 11    Violet Mclelland        Cara Losch            East
# 12       Corliss Cosme        Cara Losch            East
# 13  Rosie Papadopoulos        Cara Losch            East
# 14       Garret Kinder        Cara Losch            East
# 15      Wilburn Farren        Cara Losch            East
# 16  Elizabeth Anderson        Cara Losch            East
# 17     Daniell Hammack     Rocco Neubert            East
# 18        Cassey Cress     Rocco Neubert            East
# 19       Donn Cantrell     Rocco Neubert            East
# 20        Reed Clapper     Rocco Neubert            East
# 21           Boris Faz     Rocco Neubert            East
# 22     Natalya Ivanova     Rocco Neubert            East
# 23      Vicki Laflamme      Celia Rouche            West
# 24     Rosalina Dieter      Celia Rouche            West
# 25       Hayden Neloms      Celia Rouche            West
# 26      Markita Hansen      Celia Rouche            West
# 27        Elease Gluck      Celia Rouche            West
# 28      Carol Thompson      Celia Rouche            West
# 29      James Ascencio     Summer Sewald            West
# 30     Kary Hendrixson     Summer Sewald            West
# 31       Kami Bicknell     Summer Sewald            West
# 32           Zane Levy     Summer Sewald            West
# 33     Maureen Marcano     Summer Sewald            West
# 34            Carl Lin     Summer Sewald            West

# %%
df.head()
# Out:
#          sales_agent           manager regional_office
# 0      Anna Snelling  Dustin Brinkmann         Central
# 1     Cecily Lampkin  Dustin Brinkmann         Central
# 2  Versie Hillebrand  Dustin Brinkmann         Central
# 3    Lajuana Vencill  Dustin Brinkmann         Central
# 4        Moses Frase  Dustin Brinkmann         Central

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sales_agent      35 non-null     object
#  1   manager          35 non-null     object
#  2   regional_office  35 non-null     object
# dtypes: object(3)
# memory usage: 972.0+ bytes

# %%
df.nunique()
# Out:
# sales_agent        35
# manager             6
# regional_office     3
# dtype: int64

# %%
df.describe()
# Out:
#           sales_agent        manager regional_office
# count              35             35              35
# unique             35              6               3
# top     Anna Snelling  Melvin Marxen            East
# freq                1              6              12

# %%
df1 = pd.read_csv('pipeline_typo_fix.csv')

# %%
df1
# Out:
#      opportunity_id        sales_agent         product  account   deal_stage  \
# 0          1C1I7A6R        Moses Frase  GTX Plus Basic  Cancity          Won
# 1          Z063OYW0    Darcel Schlecht         GTX Pro    Isdom          Won
# 2          EC4QE1BX    Darcel Schlecht      MG Special  Cancity          Won
# 3          MV1LWRNH        Moses Frase       GTX Basic  Codehow          Won
# 4          PE84CX4O          Zane Levy       GTX Basic   Hatfan          Won
# ...             ...                ...             ...      ...          ...
# 8795       9MIWFW5J  Versie Hillebrand     MG Advanced      NaN  Prospecting
# 8796       6SLKZ8FI  Versie Hillebrand     MG Advanced      NaN  Prospecting
# 8797       LIB4KUZJ  Versie Hillebrand     MG Advanced      NaN  Prospecting
# 8798       18IUIUK0  Versie Hillebrand     MG Advanced      NaN  Prospecting
# 8799       8I5ONXJX  Versie Hillebrand     MG Advanced      NaN  Prospecting
#
#      engage_date  close_date  close_value
# 0     2016-10-20  2017-03-01       1054.0
# 1     2016-10-25  2017-03-11       4514.0
# 2     2016-10-25  2017-03-07         50.0
# 3     2016-10-25  2017-03-09        588.0
# 4     2016-10-25  2017-03-02        517.0
# ...          ...         ...          ...
# 8795         NaN         NaN          NaN
# 8796         NaN         NaN          NaN
# 8797         NaN         NaN          NaN
# 8798         NaN         NaN          NaN
# 8799         NaN         NaN          NaN
#
# [8800 rows x 8 columns]

# %%
#testing my csvs created at 1p 5/23/24 worked. 
df = pd.read_csv('pipeline_left_joins_cleaned_5_23_24_01.csv')
df2 = pd.read_csv('pipeline_outer_joins_cleaned_5_23_24_01.csv')

# %%
df #looks like it worked.
# Out:
#      opportunity_id        sales_agent         product               account  \
# 0          1C1I7A6R        Moses Frase  GTX Plus Basic               Cancity
# 1          Z063OYW0    Darcel Schlecht         GTX Pro                 Isdom
# 2          EC4QE1BX    Darcel Schlecht      MG Special               Cancity
# 3          MV1LWRNH        Moses Frase       GTX Basic               Codehow
# 4          PE84CX4O          Zane Levy       GTX Basic                Hatfan
# ...             ...                ...             ...                   ...
# 8795       9MIWFW5J  Versie Hillebrand     MG Advanced  No Acct Name Entered
# 8796       6SLKZ8FI  Versie Hillebrand     MG Advanced  No Acct Name Entered
# 8797       LIB4KUZJ  Versie Hillebrand     MG Advanced  No Acct Name Entered
# 8798       18IUIUK0  Versie Hillebrand     MG Advanced  No Acct Name Entered
# 8799       8I5ONXJX  Versie Hillebrand     MG Advanced  No Acct Name Entered
#
#        deal_stage engage_date  close_date  close_value series  sales_price  \
# 0             Won  2016-10-20  2017-03-01       1054.0    GTX         1096
# 1             Won  2016-10-25  2017-03-11       4514.0    GTX         4821
# 2             Won  2016-10-25  2017-03-07         50.0     MG           55
# 3             Won  2016-10-25  2017-03-09        588.0    GTX          550
# 4             Won  2016-10-25  2017-03-02        517.0    GTX          550
# ...           ...         ...         ...          ...    ...          ...
# 8795  Prospecting         NaN         NaN          NaN     MG         3393
# 8796  Prospecting         NaN         NaN          NaN     MG         3393
# 8797  Prospecting         NaN         NaN          NaN     MG         3393
# 8798  Prospecting         NaN         NaN          NaN     MG         3393
# 8799  Prospecting         NaN         NaN          NaN     MG         3393
#
#         sector  year_established  revenue  employees office_location  \
# 0       retail            2001.0   718.62     2448.0   United States
# 1      medical            2002.0  3178.24     4540.0   United States
# 2       retail            2001.0   718.62     2448.0   United States
# 3     software            1998.0  2714.90     2641.0   United States
# 4     services            1982.0   792.46     1299.0   United States
# ...        ...               ...      ...        ...             ...
# 8795       NaN               NaN      NaN        NaN             NaN
# 8796       NaN               NaN      NaN        NaN             NaN
# 8797       NaN               NaN      NaN        NaN             NaN
# 8798       NaN               NaN      NaN        NaN             NaN
# 8799       NaN               NaN      NaN        NaN             NaN
#
#          subsidiary_of           manager regional_office
# 0                  NaN  Dustin Brinkmann         Central
# 1                  NaN     Melvin Marxen         Central
# 2                  NaN     Melvin Marxen         Central
# 3     Acme Corporation  Dustin Brinkmann         Central
# 4                  NaN     Summer Sewald            West
# ...                ...               ...             ...
# 8795               NaN  Dustin Brinkmann         Central
# 8796               NaN  Dustin Brinkmann         Central
# 8797               NaN  Dustin Brinkmann         Central
# 8798               NaN  Dustin Brinkmann         Central
# 8799               NaN  Dustin Brinkmann         Central
#
# [8800 rows x 18 columns]

# %%
df2 #looks like that worked too. can start working with these two CSVs in tableau until 
#they prove problematic.
# Out:
#      opportunity_id         sales_agent         product               account  \
# 0          1C1I7A6R         Moses Frase  GTX Plus Basic               Cancity
# 1          MV1LWRNH         Moses Frase       GTX Basic               Codehow
# 2          WF4HA5NW         Moses Frase      MG Special              Ron-tech
# 3          LGI8QEC2         Moses Frase       GTX Basic             Treequote
# 4          I043RXJV         Moses Frase  GTX Plus Basic              Dontechi
# ...             ...                 ...             ...                   ...
# 8800            NaN       Mei-Mei Johns             NaN  No Acct Name Entered
# 8801            NaN  Elizabeth Anderson             NaN  No Acct Name Entered
# 8802            NaN     Natalya Ivanova             NaN  No Acct Name Entered
# 8803            NaN      Carol Thompson             NaN  No Acct Name Entered
# 8804            NaN            Carl Lin             NaN  No Acct Name Entered
#
#      deal_stage engage_date  close_date  close_value series  sales_price  \
# 0           Won  2016-10-20  2017-03-01       1054.0    GTX       1096.0
# 1           Won  2016-10-25  2017-03-09        588.0    GTX        550.0
# 2           Won  2016-11-07  2017-03-18         50.0     MG         55.0
# 3           Won  2016-12-02  2017-03-06        583.0    GTX        550.0
# 4          Lost  2016-12-03  2017-03-17          0.0    GTX       1096.0
# ...         ...         ...         ...          ...    ...          ...
# 8800        NaN         NaN         NaN          NaN    NaN          NaN
# 8801        NaN         NaN         NaN          NaN    NaN          NaN
# 8802        NaN         NaN         NaN          NaN    NaN          NaN
# 8803        NaN         NaN         NaN          NaN    NaN          NaN
# 8804        NaN         NaN         NaN          NaN    NaN          NaN
#
#                   sector  year_established  revenue  employees  \
# 0                 retail            2001.0   718.62     2448.0
# 1               software            1998.0  2714.90     2641.0
# 2                medical            1992.0  3922.42     6837.0
# 3     telecommunications            1988.0  5266.09     8595.0
# 4               software            1982.0  4618.00    10083.0
# ...                  ...               ...      ...        ...
# 8800                 NaN               NaN      NaN        NaN
# 8801                 NaN               NaN      NaN        NaN
# 8802                 NaN               NaN      NaN        NaN
# 8803                 NaN               NaN      NaN        NaN
# 8804                 NaN               NaN      NaN        NaN
#
#      office_location     subsidiary_of           manager regional_office
# 0      United States               NaN  Dustin Brinkmann         Central
# 1      United States  Acme Corporation  Dustin Brinkmann         Central
# 2      United States               NaN  Dustin Brinkmann         Central
# 3      United States            Sonron  Dustin Brinkmann         Central
# 4      United States               NaN  Dustin Brinkmann         Central
# ...              ...               ...               ...             ...
# 8800             NaN               NaN     Melvin Marxen         Central
# 8801             NaN               NaN        Cara Losch            East
# 8802             NaN               NaN     Rocco Neubert            East
# 8803             NaN               NaN      Celia Rouche            West
# 8804             NaN               NaN     Summer Sewald            West
#
# [8805 rows x 18 columns]

# %%
#are there instances of same sales agent, same engage date, clase date, account, but different op id diff product?
df['sales_agent'].value_counts()
# Out:
# sales_agent
# Darcel Schlecht       747
# Vicki Laflamme        451
# Anna Snelling         448
# Kary Hendrixson       438
# Kami Bicknell         362
# Versie Hillebrand     361
# Zane Levy             349
# Cassey Cress          346
# Jonathan Berthelot    345
# Gladys Colclough      317
# 6916            1997.0  8170.38    16499.0           Korea           NaN
# 6966            1997.0  8170.38    16499.0           Korea           NaN
# 7000            1997.0  8170.38    16499.0           Korea           NaN
# 7324            1997.0  8170.38    16499.0           Korea           NaN
# 7483            1997.0  8170.38    16499.0           Korea           NaN
# 7929            1997.0  8170.38    16499.0           Korea           NaN
#
#             manager regional_office
# 938   Melvin Marxen         Central
# 1783  Melvin Marxen         Central
# 2270  Melvin Marxen         Central
# 4014  Melvin Marxen         Central
# 4504  Melvin Marxen         Central
# 5490  Melvin Marxen         Central
# 6435  Melvin Marxen         Central
# 6916  Melvin Marxen         Central
# 6966  Melvin Marxen         Central
# 7000  Melvin Marxen         Central
# 7324  Melvin Marxen         Central
# 7483  Melvin Marxen         Central
# 7929  Melvin Marxen         Central

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8800 entries, 0 to 8799
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   opportunity_id    8800 non-null   object
#  1   sales_agent       8800 non-null   object
#  2   product           8800 non-null   object
#  3   account           8800 non-null   object
#  4   deal_stage        8800 non-null   object
#  5   engage_date       8300 non-null   object
#  6   close_date        6711 non-null   object
#  7   close_value       6711 non-null   float64
#  8   series            8800 non-null   object
#  9   sales_price       8800 non-null   int64
#  10  sector            7375 non-null   object
#  11  year_established  7375 non-null   float64
#  12  revenue           7375 non-null   float64
#  13  employees         7375 non-null   float64
#  14  office_location   7375 non-null   object
#  15  subsidiary_of     1292 non-null   object
#  16  manager           8800 non-null   object
#  17  regional_office   8800 non-null   object
# dtypes: float64(4), int64(1), object(13)
# memory usage: 1.2+ MB

# %%
df['office_location'].value_counts()
# Out:
# office_location
# United States    6120
# Korea             200
# Panama            109
# Belgium           109
# Philipines         94
# Italy              94
# Kenya              92
# Norway             91
# Jordan             88
# Japan              81
# Poland             71
# Brazil             61
# China              58
# Germany            55
# Romania            52
# Name: count, dtype: int64

# %%
#checking to see my newly cleaned left joined exported csv worked... 3:45p 5/26/24
df = pd.read_csv('all_left_joined_cntrys_fixed_5_26_24_01.csv')

# %%
df[df['office_location']=='Korea']  #used this along with .shape to verify it worked.
# Out:
# Empty DataFrame
# Columns: [opportunity_id, sales_agent, product, account, deal_stage, engage_date, close_date, close_value, series, sales_price, sector, year_established, revenue, employees, office_location, subsidiary_of, manager, regional_office]
# Index: []

# %%
df2 = pd.read_csv('all_outer_joined_cntrys_fixed_5_26_24_01.csv')

# %%
df2[df2['office_location']=='Philipines'].shape  #used this along with .shape to verify it worked. 
#done fixing country typo and incompatibility issues at the df and csv level as of 3:53pm 5/26/24
# Out:
# (0, 18)

# %%
#do we have opps where deal stage = won or deal stage = lost for which close date is null?    5/27/24  1:20pm
df = pd.read_csv('all_left_joined_cntrys_fixed_5_26_24_01.csv')

# %%
df[(df['deal_stage']=='Lost') & (df['close_date'].isna())] #no results
df[(df['deal_stage']=='Won') & (df['close_date'].isna())] #no results either
# I resolved the issue by filtering the close date range to the maximum range.  reason there was also no count was bc they had no close date (null) 
# but becase they also no deal stage of won or lost (meaning they were either prospecting or engaging).
# so their close dates were null but their count of deal stage won or lost was 0.
# Out:
# Empty DataFrame
# Columns: [opportunity_id, sales_agent, product, account, deal_stage, engage_date, close_date, close_value, series, sales_price, sector, year_established, revenue, employees, office_location, subsidiary_of, manager, regional_office]
# Index: []
